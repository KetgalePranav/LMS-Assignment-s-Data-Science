# %% [markdown]
# # Association Rule:- Book Data

# %%
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ### Check out the Data

# %%
book = pd.read_csv(r'C:\Users\PRANAV\Desktop\lms\Association rules\book.csv')

# %%
frequent_itemsets = apriori(book, min_support=0.1, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=0.7)
rules
# Out:
#           antecedents         consequents  antecedent support  \
# 0          (YouthBks)          (ChildBks)              0.2475
# 1          (ChildBks)          (YouthBks)              0.4230
# 2           (CookBks)          (ChildBks)              0.4310
# 3          (ChildBks)           (CookBks)              0.4230
# 4          (DoItYBks)          (ChildBks)              0.2820
# ..                ...                 ...                 ...
# 95  (GeogBks, ArtBks)           (CookBks)              0.1275
# 96  (CookBks, ArtBks)           (GeogBks)              0.1670
# 97          (GeogBks)   (CookBks, ArtBks)              0.2760
# 98          (CookBks)   (GeogBks, ArtBks)              0.4310
# 99           (ArtBks)  (GeogBks, CookBks)              0.2410
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.4230   0.1650    0.666667  1.576044  0.060308    1.731000
# ...

# %% [markdown]
# ### EDA

# %%
import matplotlib.pyplot as plt
rules.hist('confidence', grid = False , bins = 30)
plt.title('confidence')
# Out:
# Text(0.5, 1.0, 'confidence')

# %%
rules.hist('lift', grid = False, bins = 30)
plt.title('Lift')
# Out:
# Text(0.5, 1.0, 'Lift')

# %%
rules.sort_values('lift', ascending=False)
# Out:
#            antecedents          consequents  antecedent support  \
# 29           (CookBks)           (ItalCook)              0.4310
# 28          (ItalCook)            (CookBks)              0.1135
# 78  (ChildBks, ArtBks)            (GeogBks)              0.1625
# 79           (GeogBks)   (ChildBks, ArtBks)              0.2760
# 87            (ArtBks)  (DoItYBks, CookBks)              0.2410
# ..                 ...                  ...                 ...
# 4           (DoItYBks)           (ChildBks)              0.2820
# 12          (YouthBks)            (CookBks)              0.2475
# 13           (CookBks)           (YouthBks)              0.4310
# 3           (ChildBks)            (CookBks)              0.4230
# 2            (CookBks)           (ChildBks)              0.4310
#
#     consequent support  support  confidence      lift  leverage  conviction
# 29              0.1135   0.1135    0.263341  2.320186  0.064582    1.203406
# ...

# %%
rules[rules.lift>1]
# Out:
#           antecedents         consequents  antecedent support  \
# 0          (YouthBks)          (ChildBks)              0.2475
# 1          (ChildBks)          (YouthBks)              0.4230
# 2           (CookBks)          (ChildBks)              0.4310
# 3          (ChildBks)           (CookBks)              0.4230
# 4          (DoItYBks)          (ChildBks)              0.2820
# ..                ...                 ...                 ...
# 95  (GeogBks, ArtBks)           (CookBks)              0.1275
# 96  (CookBks, ArtBks)           (GeogBks)              0.1670
# 97          (GeogBks)   (CookBks, ArtBks)              0.2760
# 98          (CookBks)   (GeogBks, ArtBks)              0.4310
# 99           (ArtBks)  (GeogBks, CookBks)              0.2410
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.4230   0.1650    0.666667  1.576044  0.060308    1.731000
# ...

# %%
rules2 = rules.sort_values('confidence', ascending=False)

# %%
rules2.drop_duplicates(subset ='lift', keep = False, inplace = True)

# %%
rules2
# Out:
#              antecedents           consequents  antecedent support  \
# 29            (ItalCook)             (CookBks)              0.1135
# 84    (ArtBks, DoItYBks)             (CookBks)              0.1235
# 89   (GeogBks, DoItYBks)             (CookBks)              0.1325
# 95     (GeogBks, ArtBks)             (CookBks)              0.1275
# 47  (ChildBks, DoItYBks)             (CookBks)              0.1840
# 66    (GeogBks, CookBks)            (ChildBks)              0.1925
# 11             (GeogBks)            (ChildBks)              0.2760
# 7               (RefBks)            (ChildBks)              0.2145
# 1             (YouthBks)            (ChildBks)              0.2475
# 5             (DoItYBks)            (ChildBks)              0.2820
# 77    (ChildBks, ArtBks)             (GeogBks)              0.1625
# 83     (CookBks, ArtBks)            (DoItYBks)              0.1670
# 56              (RefBks)   (ChildBks, CookBks)              0.2145
# ...
